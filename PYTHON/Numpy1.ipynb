# %%
import numpy as np

# %%
array = [1,2,3,5,6]
print(type(array))
# Out:
# <class 'list'>

# %%
array = np.array(array)

# %%
print(type(array))
# Out:
# <class 'numpy.ndarray'>

# %%
print(array*2)
# Out:
# [ 2  4  6 10 12]

# %%
array = np.array([129,2,3,4,5], dtype = np.int8)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 array = np.array([129,2,3,4,5], dtype = np.int8)
#
# OverflowError: Python integer 129 out of bounds for int8

# %%
print(array.dtype)
# Out:
# int8

# %%
print(array.nbytes) #int8 = 8bit storage system
#8 bit = 1byte
#int8 int16 int32 int64 
#2^8 = 256 -128 ->0 -> 127
# Out:
# 5

# %%
array = np.array([1.2,3.2,5.], dtype = np.float16)

# %%
2**16
# Out:
# 65536

# %%
2**8
# Out:
# 256

# %%
array = np.array([-60000.,70000], dtype = np.float64)

# %%
array = np.array([129,2,3,4,5], dtype = np.int8)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 array = np.array([129,2,3,4,5], dtype = np.int8)
#
# OverflowError: Python integer 129 out of bounds for int8

# %%
array = np.array([-129,2,3,4,5], dtype = np.int8)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 array = np.array([-129,2,3,4,5], dtype = np.int8)
#
# OverflowError: Python integer -129 out of bounds for int8

# %%
array = np.array([-60000.,70000], dtype = np.float16)
# Out:
# C:\Users\Rithish krishna\AppData\Local\Temp\ipykernel_5060\2113968713.py:1: RuntimeWarning: overflow encountered in cast
#   array = np.array([-60000.,70000], dtype = np.float16)

# %%
array = np.array([-129,2,3,4,5], dtype = np.float16)

# %%
print(array.nbytes)
# Out:
# 10

# %%
array = np.array([-127,2,3,4,5], dtype = np.int8)
print(array.nbytes)
# Out:
# 5

# %%
array = np.array([-60000.,70000], dtype = np.float64)

# %%
arr = np.array([-60000, 70000], dtype=np.float16)
print(arr)
# Out:
# [-6.e+04     inf]
# C:\Users\Rithish krishna\AppData\Local\Temp\ipykernel_5060\1454159562.py:1: RuntimeWarning: overflow encountered in cast
#   arr = np.array([-60000, 70000], dtype=np.float16)

# %%
arr = np.array([-60000, 70000], dtype=np.float16)
print(arr)
# Out:
# [-6.e+04     inf]
# C:\Users\Rithish krishna\AppData\Local\Temp\ipykernel_5060\1454159562.py:1: RuntimeWarning: overflow encountered in cast
#   arr = np.array([-60000, 70000], dtype=np.float16)

# %%
array = np.array([-60000.,70000], dtype = np.float64)

# %%
array = np.array([-60000.,70000], dtype = np.str_)

# %%
print(type(array))
print(array.nbytes)
# Out:
# <class 'numpy.ndarray'>
# 64

# %%
array = np.array([-60000.,70000], dtype = np.float64)

# %%
print(type(array))
print(array.nbytes)
# Out:
# <class 'numpy.ndarray'>
# 16

# %%
array = np.array([-60000.,70000], dtype = np.str_)

# %%
print(type(array))
print(array.nbytes)
# Out:
# <class 'numpy.ndarray'>
# 64

# %%
array = np.array([-60000,70000], dtype = np.str_)
print(type(array))
print(array.nbytes)
# Out:
# <class 'numpy.ndarray'>
# 48

# %%
array = np.array([127,2,3,4,5], dtype = np.str_)
print(type(array))
print(array.nbytes)
# Out:
# <class 'numpy.ndarray'>
# 60

# %%
array = np.array([12700,2,3,4,5], dtype = np.str_)
print(array.dtype)
print(array.nbytes)
# Out:
# <U5
# 100

# %%
array = np.array([1,"hello", True], dtype = np.object_)
print(array.dtype)
print(array.nbytes)
# Out:
# object
# 24
