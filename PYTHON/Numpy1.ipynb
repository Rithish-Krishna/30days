# %%
import numpy as np

# %%
array = [1,2,3,5,6]
print(type(array))
# Out:
# <class 'list'>

# %%
array = np.array(array)

# %%
print(type(array))
# Out:
# <class 'numpy.ndarray'>

# %%
print(array*2)
# Out:
# [ 2  4  6 10 12]
