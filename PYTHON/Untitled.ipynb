# %%
import numpy as np
arr = np.array([10,20,30,10,2,44,32,323])
print(arr>20)
# Out:
# [False False  True False False  True  True  True]

# %%
brr = arr[arr>30]
print(brr)
# Out:
# [ 44  32 323]

# %%
print("The following marks are greater than 30")
print(brr)
# Out:
# The following marks are greater than 30
# [ 44  32 323]
