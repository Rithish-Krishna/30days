# %%
#Filtering -> showing only rows that satisfies a condition
import pandas as pd

df = pd.read_csv("test.csv")

it = df[df["Department"]=="IT"]

#["Department"]=="IT" -> returns true or false 
print(it)

high_salary = df[df["Salary"] > 60000]

print(high_salary)
# Out:
#    EmployeeID     Name Department  Age       City  Salary  Experience
# 0         101    Alice         IT   24    Chennai   50000           2
# 2         103  Charlie         IT   31    Chennai   70000           8
# 5         106    Frank         IT   28  Bangalore   65000           6
# 9         110     Jack         IT   25      Delhi   52000           2
#     EmployeeID     Name Department  Age       City  Salary  Experience
# 2          103  Charlie         IT   31    Chennai   70000           8
# 4          105      Eva    Finance   35     Mumbai   90000          10
# 5          106    Frank         IT   28  Bangalore   65000           6
# 8          109      Ivy    Finance   30     Mumbai   85000           8
# 11         112     Liam    Finance   29    Chennai   75000           5
